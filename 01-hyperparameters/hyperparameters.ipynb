# %% [markdown]
# # Parameter for the weeK: Number of training images

# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np
import os
import random

# import a lot of things from keras:
# sequential model
from keras.models import Sequential

# layers
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomContrast, RandomBrightness

# loss function
from keras.metrics import categorical_crossentropy

# callback functions
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# convert data to categorial vector representation
from keras.utils import to_categorical

# nice progress bar for loading data
from tqdm.notebook import tqdm

# helper function for train/test split
from sklearn.model_selection import train_test_split

# import confusion matrix helper function
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# import pre-trained model
from keras.applications.vgg16 import VGG16

# include only those gestures
CONDITIONS = ['like', 'stop']

# image size
IMG_SIZE = 64
SIZE = (IMG_SIZE, IMG_SIZE)

# number of color channels we want to use
# set to 1 to convert to grayscale
# set to 3 to use color images
COLOR_CHANNELS = 3

PATH = './gesture_dataset_sample'

# %% [markdown]
# ## helper function to load and parse annotations

# %%
annotations = dict()

for condition in CONDITIONS:
    with open(f'{PATH}/_annotations/{condition}.json') as f:
        annotations[condition] = json.load(f)

# %%
# pretty-print first element
#000484ab-5fd0-49b8-9253-23a22b71d7b1
print(json.dumps(annotations['like']['0014182f-d756-42b3-896c-c52de76926bb'], indent=2))
# Out:
# {
#   "bboxes": [
#     [
#       0.38056273,
#       0.35650891,
#       0.17322347,
#       0.10461114
#     ]
#   ],
#   "labels": [
#     "like"
#   ],
#   "landmarks": [
#     [
#       [
#         0.5497169170918876,
#         0.4276043615779976
#       ],
#       [
#         0.5218336293004483,
#         0.40536586667786917
#       ],
#       [
#         0.48288133220125257,
#         0.3930262243722419
#       ],
#       [
#         0.4501841862302019,
#         0.37981099195030416
#       ],
#       [
#         0.44251365410099686,
#         0.36620499322043343
#       ],
#       [
#         0.43138297470865106,
#         0.406093902776592
#       ],
#       [
#         0.4072660997339628,
#         0.4073950234480344
#       ],
#       [
#         0.42588200316326846,
#         0.40612291879594015
#       ],
#       [
#         0.4441470003072778,
#         0.4049221293588555
#       ],
#       [
#         0.4314493576491367,
#         0.4212979654419442
#       ],
#       [
#         0.42096276272263283,
#         0.4180224457320293
#       ],
#       [
#         0.43966095717106257,
#         0.4163441895714394
#       ],
#       [
#         0.45584443128098306,
#         0.41643247458990734
#       ],
#       [
#         0.4399742832485622,
#         0.4347478484477659
#       ],
#       [
#         0.43512361573721164,
#         0.42874760405890505
#       ],
#       [
#         0.44966112930536684,
#         0.42732603739798153
#       ],
#       [
#         0.46521777606118425,
#         0.42773384627175054
#       ],
#       [
#         0.4497130758396873,
#         0.44628828496441647
#       ],
#       [
#         0.4430629908914239,
#         0.4396031525669027
#       ],
#       [
#         0.4567531364734271,
#         0.4381686665415549
#       ],
#       [
#         0.46957149131418796,
#         0.43870709196828805
#       ]
#     ]
#   ],
#   "leading_conf": 1.0,
#   "leading_hand": "left",
#   "user_id": "6886e38c0576360baddef25fad3c0934be1dc0e192caa1c35a1785b50bd54118"
# }

# %% [markdown]
# ## helper function to pre-process images (color channel conversion and resizing)

# %%
def preprocess_image(img):
    if COLOR_CHANNELS == 1:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_resized = cv2.resize(img, SIZE)
    return img_resized

# %% [markdown]
# ## load images and annotations

# %%
images = [] # stores actual image data
labels = [] # stores labels (as integer - because this is what our network needs)
label_names = [] # maps label ints to their actual categories so we can understand predictions later

# loop over all conditions
# loop over all files in the condition's directory
# read the image and corresponding annotation
# crop image to the region of interest
# preprocess image
# store preprocessed image and label in corresponding lists
for condition in CONDITIONS:
    for filename in tqdm(os.listdir(f'{PATH}/{condition}')):
        # extract unique ID from file name
        UID = filename.split('.')[0]
        img = cv2.imread(f'{PATH}/{condition}/{filename}')
        
        # get annotation from the dict we loaded earlier
        try:
            annotation = annotations[condition][UID]
        except Exception as e:
            print(e)
            continue
        
        # iterate over all hands annotated in the image
        for i, bbox in enumerate(annotation['bboxes']):
            # annotated bounding boxes are in the range from 0 to 1
            # therefore we have to scale them to the image size
            x1 = int(bbox[0] * img.shape[1])
            y1 = int(bbox[1] * img.shape[0])
            w = int(bbox[2] * img.shape[1])
            h = int(bbox[3] * img.shape[0])
            x2 = x1 + w
            y2 = y1 + h
            
            # crop image to the bounding box and apply pre-processing
            crop = img[y1:y2, x1:x2]
            preprocessed = preprocess_image(crop)
            
            # get the annotated hand's label
            # if we have not seen this label yet, add it to the list of labels
            label = annotation['labels'][i]
            if label not in label_names:
                label_names.append(label)
            
            label_index = label_names.index(label)
            
            images.append(preprocessed)
            labels.append(label_index)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]

# %% [markdown]
# ## let's have a look at one of the images

# %%
plt.imshow(random.sample(images, 1)[0])
#plt.imshow(random.sample(images, 1)[0], cmap='gray')

# %% [markdown]
# ## split data set into train and test
#
# x is for the actual data, y is for the label (this is convention)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.20, random_state=42)
# Select
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 512
# 128
# 512
# 128

# %% [markdown]
# ## transform data sets into a format compatible with our neural network
#
# image data has to be a numpy array with following dimensions: [image_id, y_axis, x_axis, color_channels]
#
# furthermore, scale all values to a range of 0 to 1
#
# training data has to be converted to a categorial vector ("one hot"):
#
# [3] --> [0, 0, 0, 1, 0, ..., 0]

# %%
# Convert to float
X_train = np.array(X_train).astype('float32')
# Normalization [0,1]
X_train = X_train / 255.

X_test = np.array(X_test).astype('float32')
X_test = X_test / 255.


# Convert interger class labels in to one hot vector
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# rename for demonstration purposes
train_label = y_train_one_hot
test_label = y_test_one_hot

X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)

print(X_train.shape, X_test.shape, train_label.shape, test_label.shape)
# Out:
# (512, 64, 64, 3) (128, 64, 64, 3) (512, 3) (128, 3)

# %%
import time
import tensorflow as tf
# variables for hyperparameters
batch_size = 8 
epochs = 50 
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'leaky_relu'
layer_count = 2
num_neurons = 64

image_batches = [10, 50, 200, 500]
histories = {}
test_accuracies = {}
inference_times = {}

for count in image_batches:
    tf.keras.backend.clear_session()
    print(f"--- Training with {count} images ---")
    
    # Subset the training data
    X_train_subset = X_train[:count]
    y_train_subset = train_label[:count]
    
    # define model structure
    model = Sequential()
    
    model.add(RandomFlip('horizontal'))
    model.add(RandomContrast(0.1))
    
    model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
    model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))
    
    model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
    model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))
    
    model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    
    model.add(Dropout(0.2))
    model.add(Flatten())
    
    for i in range(layer_count - 1):
        model.add(Dense(num_neurons, activation=activation))
    
    model.add(Dense(num_neurons, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
    stop_early = EarlyStopping(monitor='val_loss', patience=3)
    
    history = model.fit(
        X_train_subset,
        y_train_subset,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test, test_label),
        verbose=0,
        callbacks=[reduce_lr, stop_early]
    )
    
    histories[count] = history
    
    # Get test accuracy
    loss, test_acc = model.evaluate(X_test, test_label, verbose=0)
    test_accuracies[count] = test_acc

    _ = model.predict(X_test[:1], verbose = 0)
    
    # Measure inference time for the test set
    start_time = time.time()
    model.predict(X_test, verbose=0)
    end_time = time.time()
    
    inference_time = end_time - start_time
    inference_times[count] = inference_time
# Out:
# --- Training with 10 images ---
# c:\Users\mariu\OneDrive\Studium\Tuebingen\Master\2. Semester\Interaction Techniques and Technologies\Github Classroom Aufgaben\assignment-05-cnn-mpseidel18\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000265638DEAC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# --- Training with 50 images ---
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002652FC59620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# --- Training with 200 images ---
# --- Training with 500 images ---

# %% [markdown]
# ## now, we can train the model using the fit() function
# ## this will take a while

# %%
history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)
# Out:
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9609 - loss: 0.1123 - val_accuracy: 0.9453 - val_loss: 0.1980 - learning_rate: 1.0000e-04
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9590 - loss: 0.1242 - val_accuracy: 0.9297 - val_loss: 0.1876 - learning_rate: 1.0000e-04
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9746 - loss: 0.1054 - val_accuracy: 0.9219 - val_loss: 0.2015 - learning_rate: 1.0000e-04
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9688 - loss: 0.1111 - val_accuracy: 0.9453 - val_loss: 0.1847 - learning_rate: 1.0000e-04
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9688 - loss: 0.0932 - val_accuracy: 0.9531 - val_loss: 0.1651 - learning_rate: 1.0000e-04
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9746 - loss: 0.0821 - val_accuracy: 0.9219 - val_loss: 0.1848 - learning_rate: 1.0000e-04
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9746 - loss: 0.0906 - val_accuracy: 0.9453 - val_loss: 0.1959 - learning_rate: 1.0000e-04
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9805 - loss: 0.0772 - val_accuracy: 0.9609 - val_loss: 0.1535 - learning_rate: 1.0000e-04
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9766 - loss: 0.0858 - val_accuracy: 0.9453 - val_loss: 0.1760 - learning_rate: 1.0000e-04
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9746 - loss: 0.0763 - val_accuracy: 0.9609 - val_loss: 0.1629 - learning_rate: 1.0000e-04
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9785 - loss: 0.0848 - val_accuracy: 0.9297 - val_loss: 0.1982 - learning_rate: 1.0000e-04

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast                 │ (None, 64, 64, 3)      │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 64)     │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 32)     │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 6, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 296,843 (1.13 MB)
#  Trainable params: 98,947 (386.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 197,896 (773.04 KB)

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

counts = list(test_accuracies.keys())
accuracies = list(test_accuracies.values())
times = list(inference_times.values())

# Prediction Accuracy vs Training Set Size
ax1.plot(counts, accuracies, marker='o', color='blue', linewidth=2)
ax1.set_title('Prediction Accuracy vs. Number of Training Images')
ax1.set_xlabel('Number of Training Images')
ax1.set_ylabel('Prediction Accuracy (Test Set)')
ax1.set_xticks(counts)
ax1.grid(True, linestyle='--', alpha=0.7)

# Inference Time vs Training Set Size
ax2.plot(counts, times, marker='s', color='red', linewidth=2)
ax2.set_title('Inference Time vs. Number of Training Images')
ax2.set_xlabel('Number of Training Images')
ax2.set_ylabel('Inference Time for X_test (Seconds)')
ax2.set_xticks(counts)
ax2.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# 
#  [2.95325357e-04 1.12021466e-04 9.99592721e-01]
#  [1.21189783e-04 9.99384522e-01 4.94281470e-04]
#  [1.44326538e-02 4.26365033e-04 9.85140920e-01]
#  [5.90925156e-05 2.85568717e-06 9.99938011e-01]
#  [1.00000000e+00 3.01230827e-08 4.47345272e-09]
#  [1.16433827e-02 3.90119548e-03 9.84455466e-01]
#  [1.00000000e+00 5.90010885e-08 8.23481117e-10]
#  [9.99968886e-01 2.97089173e-05 1.47569335e-06]
#  [9.99492288e-01 1.34634451e-04 3.73101706e-04]
#  [1.15829695e-03 9.98698831e-01 1.42884630e-04]
#  [2.03806115e-03 9.92974401e-01 4.98753740e-03]
#  [1.74652293e-01 3.80171835e-01 4.45175797e-01]
#  [1.30343710e-06 5.13447240e-08 9.99998689e-01]
#  [8.90343450e-04 9.99074101e-01 3.55638767e-05]
#  [5.77680729e-02 2.19320476e-01 7.22911417e-01]
#  [6.62001185e-05 7.97830580e-06 9.99925852e-01]
#  [9.99988079e-01 1.15227676e-05 3.66214067e-07]
#  [9.76868391e-01 1.12950569e-04 2.30186693e-02]
#  [3.41974956e-04 2.24099797e-03 9.97416973e-01]
#  [6.71595940e-03 9.15136099e-01 7.81479180e-02]
#  [5.44144830e-04 6.04867819e-04 9.98850942e-01]
#  [2.36295210e-03 9.95006680e-01 2.63034226e-03]
#  [1.07540786e-02 1.77714217e-04 9.89068210e-01]
#  [9.99951720e-01 2.68207568e-05 2.14169468e-05]
#  [1.07785827e-03 5.85709922e-02 9.40351188e-01]
#  [1.46767825e-01 2.73781386e-03 8.50494385e-01]
#  [6.47816887e-06 1.90584484e-04 9.99803007e-01]]
# probabilities [2 0 0 2 0 0 0 1 0 0 2 1 0 2 0 2 1 2 1 2 2 2 1 2 0 2 2 2 0 2 2 2 0 0 0 0 0
#  0 1 1 1 2 0 1 1 0 2 0 2 0 2 1 2 2 0 0 0 2 0 2 1 0 2 0 2 2 1 2 1 0 2 0 0 0
#  2 1 0 2 2 0 0 2 1 0 2 0 0 1 0 2 2 2 0 2 1 0 0 2 1 0 1 2 1 2 2 0 2 0 0 0 1
#  1 2 2 1 2 2 0 0 2 1 2 1 2 0 2 2 2]

# %% [markdown]
# ## let's test our model in action

# %%
# for mac users: you may have to add time.sleep(1) as the mac camera has a short fade in time. Furthermore possibly it will select your IPhone camera: you can deactivate this
cap = cv2.VideoCapture(0)
ret, frame = cap.read()
if COLOR_CHANNELS == 1:
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
cap.release()
plt.imshow(frame)

# %% [markdown]
# ## manual cropping for demonstration purposes - you can do better!

# %%
cropped = frame[190:320, 200:350]
plt.imshow(cropped)

# %%
resized = cv2.resize(cropped, SIZE)#[20:350, 200:420], SIZE)
plt.imshow(resized)
resized.shape
# Out:
# (64, 64, 3)

# %%
reshaped = resized.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)
reshaped.shape
prediction = model.predict(reshaped)

print(label_names[np.argmax(prediction)], np.max(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# no_gesture 1.0

# %%
# Extracts the learned parameters from layer 2 (the first convolution layer)
filters, biases = model.layers[2].get_weights()
# kernel height, kernel width, input channels, num filters -> 64 filters, each 9x9 patch across 3 color channels
print(filters.shape)

fig, axes = plt.subplots(8, 8, figsize=(20, 20))

for i in range(8):
    for j in range(8):
        img = filters[:,:,:,i*8+j] * (1 / np.max(filters))
        axes[i][j].imshow(img)
# Out:
# (9, 9, 3, 64)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.56287116..0.43623012].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8863782..0.76878643].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8710215..0.56281835].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7251971..0.58968735].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.636287..0.42271888].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.57882714..0.6176352].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.045768..0.71472335].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4680486..0.39692795].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.45698008..0.4517206].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5902749..0.44945362].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6105098..0.54736906].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8367209..0.6644655].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.48260477..0.3892818].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0355105..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.81747603..0.70293367].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.55365425..0.42140314].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6029438..0.6376331].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.58287877..0.7348137].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6679189..0.636583].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5849249..0.5587627].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5688197..0.3762045].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.74878424..0.52833223].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.45442003..0.45101467].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.67889035..0.4832382].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5745131..0.5360523].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.60142475..0.41860363].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.99932724..0.8010971].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8402885..0.68204445].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.55247116..0.5792321].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.69192696..0.44467175].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7820438..0.6418939].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6810502..0.580102].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6412426..0.4631717].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8467891..0.47872165].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.53968376..0.34336367].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.95535135..0.63252777].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7310176..0.672273].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.44256464..0.5578501].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.48208398..0.3940671].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.54029125..0.494954].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.67963153..0.46609482].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.46406442..0.40120122].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7394612..0.49156347].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.60303485..0.63000894].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.683833..0.6850837].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.70118225..0.50127935].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.56353337..0.4718973].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6016881..0.4925726].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.68969893..0.5452998].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.77809834..0.7921287].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.76149964..0.6620055].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51758474..0.51620644].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.42730492..0.5213017].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8484154..0.62224674].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.74545515..0.5029673].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4126946..0.38353544].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.56991404..0.44620678].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.656812..0.52949077].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6110601..0.5249652].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.74720764..0.6432267].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4686083..0.44094887].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6880489..0.4275881].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.65542394..0.47046444].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8903877..0.7433269].

# %%
fig, axes = plt.subplots(8, 8, figsize=(20, 20))

for i in range(8):
    for j in range(8):
        #axes[i][j].imshow(filters[:,:,:,i*8+j] * 255, 'gray')
        
        # only channle 0 for demonstration purposes
        kernel = filters[:,:,0,i*8+j]

        #print(kernel.shape)

        gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
        filtered = cv2.filter2D(gray, -1, kernel)

        axes[i][j].imshow(filtered, 'gray')

# %% [markdown]
# ## Transfer Learning
#
# let's use a pre-trained model (VGG16) for our prediction
#
# note that VGG16 needs three color channels

# %%
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'leaky_relu'  # LeakyReLU
layer_count = 2
num_neurons = 256

# load a VGG16 model trained on the imagenet dataset
# include_top=False -> do not include the output layer
# input_tensor -> tells the model about the dimensions of our images (VGG16 needs three color channels)
# pooling -> which type of pooling to use between convolutions; max or avg seem to be the best
VGG = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)), pooling='max')

# we want to use the VGG's original weights -> make those layers untrainable
for layer in VGG.layers:
    layer.trainable = False

# build a new model and add the VGG layers
model_vgg = Sequential()
model_vgg.add(VGG)

# append dense layers at the end
for i in range(layer_count - 1):
    model_vgg.add(Dense(num_neurons, activation=activation))
model_vgg.add(Dropout(0.2))

model_vgg.add(Dense(num_neurons, activation=activation))

# classifier
model_vgg.add(Dense(num_classes, activation='softmax'))

model_vgg.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

# %%
history_vgg = model_vgg.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)
# Out:
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7051 - loss: 0.6744 - val_accuracy: 0.8438 - val_loss: 0.4121 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8633 - loss: 0.3157 - val_accuracy: 0.8828 - val_loss: 0.2989 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9492 - loss: 0.1633 - val_accuracy: 0.8750 - val_loss: 0.2906 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9570 - loss: 0.1489 - val_accuracy: 0.8828 - val_loss: 0.3258 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9668 - loss: 0.1000 - val_accuracy: 0.8984 - val_loss: 0.2046 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9355 - loss: 0.1489 - val_accuracy: 0.9219 - val_loss: 0.1993 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9883 - loss: 0.0674 - val_accuracy: 0.9453 - val_loss: 0.1629 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9922 - loss: 0.0529 - val_accuracy: 0.8594 - val_loss: 0.5186 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9805 - loss: 0.0625 - val_accuracy: 0.9297 - val_loss: 0.1916 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9902 - loss: 0.0345 - val_accuracy: 0.9297 - val_loss: 0.1625 - learning_rate: 3.0000e-04
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9980 - loss: 0.0192 - val_accuracy: 0.9219 - val_loss: 0.1631 - learning_rate: 3.0000e-04
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9961 - loss: 0.0160 - val_accuracy: 0.9375 - val_loss: 0.1231 - learning_rate: 3.0000e-04
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9961 - loss: 0.0169 - val_accuracy: 0.9219 - val_loss: 0.1707 - learning_rate: 3.0000e-04
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9961 - loss: 0.0152 - val_accuracy: 0.9219 - val_loss: 0.1683 - learning_rate: 3.0000e-04
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9609 - val_loss: 0.1457 - learning_rate: 1.0000e-04

# %%
model_vgg.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 512)            │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,308,363 (58.40 MB)
#  Trainable params: 197,891 (773.01 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
#  Optimizer params: 395,784 (1.51 MB)

# %%
loss = history_vgg.history['loss']
val_loss = history_vgg.history['val_loss']
accuracy = history_vgg.history['accuracy']
val_accuracy = history_vgg.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
# let the model make predictions for our training data
y_predictions = model_vgg.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# before [[4.31112736e-01 3.19309160e-03 5.65694094e-01]
#  [9.99933720e-01 5.97948092e-05 6.46573926e-06]
#  [9.84724939e-01 1.19765485e-02 3.29846377e-03]
#  [1.01384543e-01 2.06922926e-03 8.96546185e-01]
#  [9.99999881e-01 1.16424424e-07 1.90913707e-09]
#  [9.99988079e-01 1.17862392e-05 9.58747179e-08]
#  [9.99996781e-01 7.03975502e-07 2.50291077e-06]
#  [7.85077806e-04 9.99213696e-01 1.14682382e-06]
#  [9.99999881e-01 3.59359618e-08 6.91462745e-08]
#  [9.99453008e-01 5.41980437e-04 5.00399892e-06]
#  [7.63839054e-08 5.71407725e-07 9.99999285e-01]
#  [3.51748895e-05 9.99859214e-01 1.05554507e-04]
#  [9.84860480e-01 1.88272831e-03 1.32568469e-02]
#  [3.89102497e-05 2.94176584e-06 9.99958158e-01]
#  [9.99999762e-01 1.97149660e-07 3.50850939e-08]
#  [1.90277901e-02 2.32365411e-02 9.57735717e-01]
#  [2.80362110e-05 9.98867750e-01 1.10422354e-03]
#  [6.68224175e-07 1.24325965e-07 9.99999166e-01]
#  [4.39351279e-05 9.99931812e-01 2.42023416e-05]
#  [1.04986492e-03 5.48885055e-07 9.98949587e-01]
#  [9.37995374e-01 1.68997571e-02 4.51048426e-02]
#  [1.01263026e-06 3.18202886e-08 9.99999046e-01]
#  [3.17671075e-02 9.67998505e-01 2.34414867e-04]
#  [8.86972703e-06 3.20780077e-06 9.99987960e-01]
#  [9.99984145e-01 1.28994943e-05 3.03893057e-06]
#  [9.01713781e-03 3.25280754e-03 9.87730086e-01]
#  [4.11294634e-04 1.14102349e-05 9.99577224e-01]
#  [2.17746037e-06 2.28764839e-06 9.99995589e-01]
#  [9.99437273e-01 5.62002242e-04 7.12699944e-07]
#  [2.95116636e-03 2.67583062e-04 9.96781230e-01]
#  [3.69906934e-06 3.44830795e-07 9.99995947e-01]
#  [1.06930779e-03 1.49976077e-05 9.98915672e-01]
#  [9.99998569e-01 1.25288034e-06 1.60500420e-07]
